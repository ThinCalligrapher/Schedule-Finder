// %%
#include <iostream>

char message [5] {'H', 'e', 'l', 'l', 'o'}
// this one was about character arays
// so turns out programming might actually be about how to just use packages

// %%
for( auto c : message) { // this one is a for loop using the enumeration? : operator on an iterator and a character array auto c
    std::cout << c << std::endl;
}
// Out:
// H
// e
// l
// l
// o

// %%
for (auto c : message)

// %%
std::size(message)
// Out:
// 5

// %%
int arr[] = {1,2, 3, 4, 5};

// %%
arr
// Out:
// { 1, 2, 3, 4, 5 }

// %%
std::size(arr)
// Out:
// 5

// %% [markdown]
// # charactes arrays

// %%
// only proper C strings can be printed on the console
char message[4] = {'a', 'b', 'c'};
std::cout << message << std::endl;
// Out:
// abc

// %%
message[3];

// %%
// lets see if pointers work in this!

// %%
int x {4};
int* p = &x;

// %%
&x;

// %%
std::cout << &x;
std::cout << "\n" << p;
// Out:
// 0x7e3dfae89058
// 0x7e3dfae89058

// %%
#include <iostream>
int x {5};
do {
    std::cout << "Hey" << std::endl;
    x--;
} while(x > 0);
// Out:
// Hey
// Hey
// Hey
// Hey
// Hey

// %%
int arr[] = {1, 2, 3, 4, 5, 6, 7};
int sum {};
std::cout << sum << std::endl;
for(int x : arr) {
    sum = sum +  x;
}
std::cout << sum;
// Out:
// 0
// 28

// %%
printf("%zu", std::size(arr));
// Out:
// 7

// %%
int arr[5] = {1, 2, 3};

// %%
char string[] = {"Hello"}; // so this is the right way to allocate at compile time a character array
char string2[6] = {"Hello"}; // not allowed in this version to make it 5 due to compiler!

// %%
std::cout << string;
// Out:
// Hello

// %%
std::cout << string2;
// Out:
// Hello

// %%
// Good ways to use a pointer and strings?
#include <string>
int x {50};
int* p{&x};
std::string word {"Hello"};

// %%
// Bad ways to use a pointer
// Lets start at assigning data to a place it should not be
// int* p {33}; bad address
// or int* p; garbage address
// then *p = 5000 this will set the value at god knows where to 5000 which can crash your computer? A program. IDK
